# %%
import io
import glob
import cv2
import PIL.Image
import numpy as np

from natsort import natsorted
from matplotlib import pyplot as plt
from util.WordSegmentation import wordSegmentation, prepareImg
from IPython.display import clear_output, Image, display
from skimage.morphology import skeletonize

# %%
input_files = 'output_files/image-data/image-data/'

# %%
def showarray(a, fmt='jpeg'):
    a = np.uint8(np.clip(a, 0, 255))
    f = io.BytesIO()
    PIL.Image.fromarray(a).save(f, fmt)
    display(Image(data=f.getvalue()))

# %%
def load_slices(filepath):
    slices = []
    slices_filepath = filepath + '/'
    slices_path = natsorted(glob.glob(slices_filepath + 'slice*_binarize.png'))
    for slice_path in slices_path:
        slices.append(prepareImg(cv2.imread(slice_path), 50))  
    return slices

# %%
image_filepaths = glob.glob(input_files + '*')
images = []
for image_filepath in image_filepaths:
    images.append(load_slices(image_filepath))

showarray(images[15][2])

# %%
# temp = images[15][2].astype('uint8')
# temp = cv2.bitwise_not(temp)
temp = images[15][2]
ret, temp = cv2.threshold(temp, 127, 255, cv2.THRESH_BINARY)
showarray(temp)
print(temp.max())
temp = skeletonize(temp)
showarray(temp)
kernel = np.ones((2,2), np.uint8)
erosion = cv2.erode(temp, kernel, iterations = 1)
showarray(erosion)
# Out:
# 255
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ab19ecc7967a> in <module>()
#       5 showarray(temp)
#       6 print(temp.max())
# ----> 7 temp = skeletonize(temp)
#       8 showarray(temp)
#       9 kernel = np.ones((2,2), np.uint8)
#
# c:\users\joppe\anaconda3\envs\tensorflow\lib\site-packages\skimage\morphology\_skeletonize.py in skeletonize(image)
#      97         raise ValueError('Skeletonize requires a 2D array')
#      98     if not np.all(np.in1d(image.flat, (0, 1))):
# ---> 99         raise ValueError('Image contains values other than 0 and 1')
#     100
#     101     return _fast_skeletonize(image)
#
# ValueError: Image contains values other than 0 and 1

# %%
h, w = erosion.shape
# print(h, w)
# print(len(erosion[0]))
# print(len(erosion[:][2]))
# print(erosion[:][0])

histogram = np.zeros((w,), dtype=int)
for idx0, vertical_line in enumerate(erosion[:]):
    for idx1, value in enumerate(vertical_line):
        if value < 10:
            histogram[idx1] += 1
plt.plot(histogram)
